# %% [markdown]
# ## 1. Описание датасета и задания

# %% [markdown]
# Представлен датасет с данными о 5000 фильмах, имеющих наибольший рейтинг на сайте IMDb (датасет выложен на платформе [Kaggle](https://www.kaggle.com/datasets/totoro29/imdb-movies)).

# %% [markdown]
# ***Информация, содержащаяся в датасете:***
# 1.   Ссылка на постер фильма (poster).
# 2.   Наименование фильма (title).
# 3.   Класс фильма по рейтингу the British Board of Film Classification (BBFC) (certificate).
# 4.   Продолжительность фильма (runtime).
# 5.   Жанр фильма (genre).
# 6.   Рейтинг фильма на платформе IMBD (rating).
# 7.   Описание сюжета фильма (about).
# 8.   Кинорежиссер фильма (director).
# 9.   Актеры-звезды фильма (stars).
# 10.  Количество проголосовавших за фильм (votes).
# 11.  Доход с фильма (gross_earn).

# %% [markdown]
# ## 2. Загрузка датасета

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-7c026907-a12e-41b8-a6a5-632169e6d242" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c026907-a12e-41b8-a6a5-632169e6d242">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 3. Подгрузка данных в питон и начало работы с ними

# %%
import pandas as pd

# %%
dataset = pd.read_csv('movies_clean_1.csv')

# %%
dataset.head(2)
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime          genre  rating  \
# 0  The Shawshank Redemption          15  142 min          Drama     9.3
# 1            Hababam Sinifi         12A   87 min  Comedy, Drama     9.2
#
#                                                about        director  \
# 0  Two imprisoned men bond over a number of years...  Frank Darabont
# 1  Lazy, uneducated students share a very close b...   Ertem Egilmez
#
#                                                stars      votes gross_earn  \
# 0  ('Tim Robbins',), ('Morgan Freeman',), ('Bob G...  26,26,905    $28.34M
# 1  ('Kemal Sunal',), ('Münir Özkul',), ('Halit Ak...     40,492        NaN
#
#    runtime_clear  gross_earn_clear
# 0            142             28.34
# 1             87               NaN

# %%
#dataset.drop(columns='Unnamed: 0', inplace=True)
#у меня нет столбца Unnamed: 0, что не так?

# %% [markdown]
# ## 4. Оценка размеров датасета, выбор признаков для анализа

# %%
dataset.shape
# Out:
# (4970, 13)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4970 entries, 0 to 4969
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   poster            4970 non-null   object
#  1   title             4970 non-null   object
#  2   certificate       4970 non-null   object
#  3   runtime           4970 non-null   object
#  4   genre             4970 non-null   object
#  5   rating            4970 non-null   float64
#  6   about             4956 non-null   object
#  7   director          4970 non-null   object
#  8   stars             4970 non-null   object
#  9   votes             4970 non-null   object
#  10  gross_earn        4574 non-null   object
#  11  runtime_clear     4970 non-null   int64
#  12  gross_earn_clear  4574 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 504.9+ KB

# %% [markdown]
# ## 5. Неграфический и графический анализ количественных признаков

# %% [markdown]
# ### *5.1. gross_earn_clear*

# %%
gross_earn = dataset['gross_earn_clear']

# %%
max_value = max(gross_earn)
min_value = min(gross_earn)
print('Наибольший доход: ', max_value, 'Наименьший доход: ', min_value)
# Out:
# Наибольший доход:  936.66 Наименьший доход:  0.0

# %%
dataset[dataset['gross_earn_clear']==0.0]
# Out:
#                                                  poster  \
# 540   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 736   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1381  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1453  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1567  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2120  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2364  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3153  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3332  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3638  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3786  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3837  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3962  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4319  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4342  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4799  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
# ...

# %%
gross_earn = dataset[dataset['gross_earn_clear']!=0.0]['gross_earn_clear']
gross_earn
# Out:
# 0        28.34
# 1          NaN
# 2       134.97
# 3        57.30
# 4        96.90
#          ...
# 4965     10.25
# 4966     14.19
# 4967      0.03
# 4968      4.92
# 4969      9.11
# Name: gross_earn_clear, Length: 4954, dtype: float64

# %%
max_value = max(gross_earn)
min_value = min(gross_earn)
print('Наибольший доход: ', max_value, 'Наименьший доход: ', min_value)
# Out:
# Наибольший доход:  936.66 Наименьший доход:  0.01

# %%
mean_value = gross_earn.mean()
print('Средний доход с фильма: ', mean_value)
# Out:
# Средний доход с фильма:  49.07882623957876

# %%
median_value = gross_earn.median()
print('Медиана доходов фильмов: ', median_value)
# Out:
# Медиана доходов фильмов:  28.345

# %%
percentile_10_value = gross_earn.quantile(0.1)
percentile_25_value = gross_earn.quantile(0.25)
percentile_50_value = gross_earn.quantile(0.5)
percentile_75_value = gross_earn.quantile(0.75)
percentile_90_value = gross_earn.quantile(0.9)
print('10-й процентиль доходов фильмов: ', percentile_10_value)
print('25-й процентиль доходов фильмов: ', percentile_25_value)
print('50-й процентиль доходов фильмов: ', percentile_50_value)
print('75-й процентиль доходов фильмов: ', percentile_75_value)
print('90-й процентиль доходов фильмов: ', percentile_90_value)
# Out:
# 10-й процентиль доходов фильмов:  0.7970000000000005
# 25-й процентиль доходов фильмов:  7.0
# 50-й процентиль доходов фильмов:  28.345
# 75-й процентиль доходов фильмов:  63.04
# 90-й процентиль доходов фильмов:  121.96800000000002

# %%
gross_earn.describe()
# Out:
# count    4558.000000
# mean       49.078826
# std        67.171717
# min         0.010000
# 25%         7.000000
# 50%        28.345000
# 75%        63.040000
# max       936.660000
# Name: gross_earn_clear, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(gross_earn)
plt.title('gross_earn')
plt.show()

# %%
gross_earn_without_na = gross_earn.dropna()
#gross_earn_without_na.isna().sum() -проверка

# %%
plt.boxplot(gross_earn_without_na)
plt.show()

# %%
plt.hist(gross_earn_without_na)
plt.show()

# %%
gross_earn_2 = dataset[
    (dataset['gross_earn_clear']>=percentile_10_value)&
    (dataset['gross_earn_clear']<=percentile_90_value)]['gross_earn_clear']

# %%
plt.hist(gross_earn_2, bins=20)
plt.show()

# %%
plt.boxplot(gross_earn_2)
plt.show()

# %% [markdown]
# **Выводы:**
#
# **1)** max:  936.66| min:  0.01
# из полученных данных можно сделать вывод, что между макс значением и мин значением есть большая разница. а мин значение плюс ко всему является чуть больше 0
#
# **2)** нулевые значения есть, предобработка нужна. это было сделано с помощью метода dropna(), где мы удалили строки с пропущенными значениями
#
# **3)** среднее значение это сумма элементов поделенная на количество, а медиана это среднее число на линии(по возрастанию) состоящей из элементов. это их различие
#
# **4)** 10-й процентиль доходов фильмов:  0.7970000000000005
#
# 25-й процентиль доходов фильмов:  7.0
#
# 50-й процентиль доходов фильмов:  28.345
#
# 75-й процентиль доходов фильмов:  63.04
#
# 90-й процентиль доходов фильмов:  121.96800000000002
#
# из полученных данных можно понять, что 0.797 это значение ниже которого находится 10% итд для других процентилей
#
# **5)** при использовании boxplot() стало понятно, что есть выбросы которые мешают правильно проанализировать данные, а именно отдельные точки на графике выше значения 600. следовательно их нужно было убрать, после этого значения изменились.
#
# boxplot() показывает прямоугольник - это значение между процентилями 0,25 0,75
# полоса на нем - это медиана (процентиль 0,5)
#
# гистограмма показывает с какой частотой элемент появляется в том или ином отрезке значений

# %% [markdown]
# ### **5.2. runtime_clear*

# %%
dataset.head(3)
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime          genre  rating  \
# 0  The Shawshank Redemption          15  142 min          Drama     9.3
# 1            Hababam Sinifi         12A   87 min  Comedy, Drama     9.2
# 2             The Godfather           X  175 min   Crime, Drama     9.2
#
#                                                about              director  \
# 0  Two imprisoned men bond over a number of years...        Frank Darabont
# 1  Lazy, uneducated students share a very close b...         Ertem Egilmez
# 2  The aging patriarch of an organized crime dyna...  Francis Ford Coppola
#
#                                                stars      votes gross_earn  \
# 0  ('Tim Robbins',), ('Morgan Freeman',), ('Bob G...  26,26,905    $28.34M
# ...

# %% [markdown]
# По аналогии проанализируйте продолжительность фильмов

# %%
dataset['runtime_clear'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4970 entries, 0 to 4969
# Series name: runtime_clear
# Non-Null Count  Dtype
# --------------  -----
# 4970 non-null   int64
# dtypes: int64(1)
# memory usage: 39.0 KB

# %%
dataset['runtime_clear'].isna().sum()
# Out:
# 0

# %%
#dataset['runtime_clear'].sort_values()

# %%
max_v = dataset['runtime_clear'].max()
min_v = dataset['runtime_clear'].min()
mean_v = dataset['runtime_clear'].mean()
print('max:', max_v, 'min:', min_v, 'mean:', mean_v)
# Out:
# max: 366 min: 45 mean: 110.26760563380282

# %%
dataset['runtime_clear'].describe()
# Out:
# count    4970.000000
# mean      110.267606
# std        21.441886
# min        45.000000
# 25%        96.000000
# 50%       106.000000
# 75%       120.000000
# max       366.000000
# Name: runtime_clear, dtype: float64

# %%
plt.boxplot(dataset['runtime_clear'])
plt.show()
#тут явно есть выбросы, следовательно их нужно убрать

# %%
percentile_10_v = dataset['runtime_clear'].quantile(0.05)
percentile_90_v = dataset['runtime_clear'].quantile(0.96)

runtime_clear = dataset[
    (dataset['runtime_clear']>=percentile_10_v)&
    (dataset['runtime_clear']<=percentile_90_v)]['runtime_clear']

runtime_clear
# Out:
# 0       142
# 1        87
# 5        96
# 7       152
# 8       154
#        ...
# 4964     94
# 4965     90
# 4966     87
# 4967     91
# 4969     88
# Name: runtime_clear, Length: 4571, dtype: int64

# %%
plt.boxplot(runtime_clear)
plt.show()

# %%
plt.hist(runtime_clear)
plt.show()

# %% [markdown]
# ## 6. Неграфический и графический анализ категориальных признаков

# %% [markdown]
# ### *6.1. certificate*

# %% [markdown]
# Описание классификации [the British Board of Film Classification (BBFC)]( https://www.bbfc.co.uk/about-classification/classification-guidelines)

# %%
dataset['certificate'].describe()
# Out:
# count     4970
# unique      15
# top         15
# freq      1843
# Name: certificate, dtype: object

# %%
uni = dataset['certificate'].unique()
print(uni)
# Out:
# ['15' '12A' 'X' 'U' '18' 'PG' '12' 'A' 'AA' 'R' 'Not Rated' 'Rejected'
#  'UA' 'PG-13' '(Banned)']

# %%
dataset['certificate'].value_counts()
# Out:
# certificate
# 15           1843
# 12A           788
# 18            659
# PG            614
# U             362
# 12            278
# A             186
# X             134
# AA             59
# R              12
# UA             11
# PG-13          11
# Not Rated       7
# Rejected        5
# (Banned)        1
# Name: count, dtype: int64

# %%
certificate_counts = dataset['certificate'].value_counts().sort_values(ascending=True)
a = certificate_counts.values
b = certificate_counts.index
print(a, b)
# Out:
# [   1    5    7   11   11   12   59  134  186  278  362  614  659  788
#  1843] Index(['(Banned)', 'Rejected', 'Not Rated', 'UA', 'PG-13', 'R', 'AA', 'X', 'A',
#        '12', 'U', 'PG', '18', '12A', '15'],
#       dtype='object', name='certificate')

# %%
plt.barh(b, a)
plt.title('Столбчатая диаграмма распределения фильмов по классам')
plt.show()

# %%
certificate_counts_top_5 = dataset['certificate'].value_counts()[:5]
certificate_counts_top_5
# Out:
# certificate
# 15     1843
# 12A     788
# 18      659
# PG      614
# U       362
# Name: count, dtype: int64

# %%
plt.pie(certificate_counts_top_5.values, labels=certificate_counts_top_5.index, autopct='%.1f%%')
plt.show()

# %% [markdown]
# **Выводы:**
#
# 1) количество уникальных значений равно 15-ти
#
# 2) самый часто встречаемый признак - 15, он встретился 1843 раз
#
# 3) тут главный вопрос что значит встречается часто :))
# для меня часто это больше 250-ти, следовательно чаще всего встречается 6 значений, а именно:
#
# 15 	1843
#
# 12A 	788
#
# 18 	659
#
# PG 	614
#
# U 	362
#
# 12 	278
#
# следовательно наименее часто встречаются 9 значений, а именно:
#
# A 	186
#
# X 	134
#
# AA 	59
#
# R 	12
#
# UA 	11
#
# PG-13 	11
#
# Not Rated 	7
#
# Rejected 	5
#
# (Banned) 	1
#
# 4) barh показывает что значение 15 встречается чаще всего, тоже самое показывает и pie, но еще и с процентным соотношением, а именно 43,2%

# %% [markdown]
# ### **6.2. rating*

# %%
dataset['rating']
# Out:
# 0       9.3
# 1       9.2
# 2       9.2
# 3       9.0
# 4       9.0
#        ...
# 4965    2.1
# 4966    1.9
# 4967    1.9
# 4968    1.9
# 4969    1.5
# Name: rating, Length: 4970, dtype: float64

# %%
dataset['rating'].describe()
# Out:
# count    4970.000000
# mean        6.694004
# std         0.967945
# min         1.500000
# 25%         6.100000
# 50%         6.800000
# 75%         7.400000
# max         9.300000
# Name: rating, dtype: float64

# %%
rating_count = dataset['rating'].value_counts()
rating_count
# Out:
# rating
# 6.7    221
# 6.4    218
# 6.6    209
# 7.2    207
# 7.0    206
#       ...
# 2.1      1
# 9.3      1
# 2.3      1
# 8.9      1
# 1.5      1
# Name: count, Length: 72, dtype: int64

# %%
plt.barh(rating_count.index, rating_count.values)
plt.show()

# %%
plt.pie(rating_count.values, labels = rating_count.index)
plt.title('Круговая диаграмма')
plt.show()

# %% [markdown]
# ### **6.3. director*

# %%
dataset['director']
# Out:
# 0             Frank Darabont
# 1              Ertem Egilmez
# 2       Francis Ford Coppola
# 3       Francis Ford Coppola
# 4           Steven Spielberg
#                 ...
# 4965                Uwe Boll
# 4966         Jason Friedberg
# 4967              Tom Putnam
# 4968           Robert Iscove
# 4969               Bob Clark
# Name: director, Length: 4970, dtype: object

# %%
dataset['director'].describe()
# Out:
# count            4970
# unique           1954
# top       Woody Allen
# freq               38
# Name: director, dtype: object

# %%
director_values = dataset['director'].value_counts()
director_values
# Out:
# director
# Woody Allen           38
# Clint Eastwood        27
# Steven Spielberg      27
# Alfred Hitchcock      24
# Ridley Scott          21
#                       ..
# Sebastian Schipper     1
# Jerry Zaks             1
# Kinji Fukasaku         1
# Robin Swicord          1
# Tom Putnam             1
# Name: count, Length: 1954, dtype: int64

# %%
filtered_value_counts = director_values[director_values >= 5]
filtered_value_counts
#убрала режиссеров со значением меньше 5
# Out:
# director
# Woody Allen          38
# Clint Eastwood       27
# Steven Spielberg     27
# Alfred Hitchcock     24
# Ridley Scott         21
#                      ..
# Harald Zwart          5
# Martin Brest          5
# Jonathan Levine       5
# David Ayer            5
# Richard Fleischer     5
# Name: count, Length: 274, dtype: int64

# %%
plt.figure(figsize=(8, 6))  # Ширина x Высота
plt.barh(filtered_value_counts.index[:50], filtered_value_counts.values[:50])
#пришлось уменьшить количество индексов и значений ибо их было слишком много и нельзя было прочитать график
# Уменьшение размера шрифта меток
plt.yticks(fontsize=8)
plt.show()

# %%
plt.pie(filtered_value_counts.values[:50], labels = filtered_value_counts.index[:50])
plt.show()

# %% [markdown]
# ## 7. Анализ взаимосвязи двух количественных признаков

# %% [markdown]
# ### *7.1. runtime_clear - gross_earn_clear*

# %%
dataset.head(2)
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime          genre  rating  \
# 0  The Shawshank Redemption          15  142 min          Drama     9.3
# 1            Hababam Sinifi         12A   87 min  Comedy, Drama     9.2
#
#                                                about        director  \
# 0  Two imprisoned men bond over a number of years...  Frank Darabont
# 1  Lazy, uneducated students share a very close b...   Ertem Egilmez
#
#                                                stars      votes gross_earn  \
# 0  ('Tim Robbins',), ('Morgan Freeman',), ('Bob G...  26,26,905    $28.34M
# 1  ('Kemal Sunal',), ('Münir Özkul',), ('Halit Ak...     40,492        NaN
#
#    runtime_clear  gross_earn_clear
# 0            142             28.34
# 1             87               NaN

# %%
import seaborn as sns

# %%
sns.jointplot(x=dataset['runtime_clear'], y=dataset['gross_earn_clear'],size=10, alpha=0.2)
plt.show()

# %%
columns = ['runtime_clear', 'gross_earn_clear']
g = sns.PairGrid(dataset[columns])
g.map(sns.scatterplot, alpha=0.2)

# %%
print(dataset['gross_earn_clear'].describe(), dataset['runtime_clear'].describe())
# Out:
# count    4574.000000
# mean       48.907147
# std        67.116697
# min         0.000000
# 25%         6.797500
# 50%        28.085000
# 75%        62.572500
# max       936.660000
# Name: gross_earn_clear, dtype: float64 count    4970.000000
# mean      110.267606
# std        21.441886
# min        45.000000
# 25%        96.000000
# 50%       106.000000
# 75%       120.000000
# max       366.000000
# Name: runtime_clear, dtype: float64

# %%
new_dataset = dataset.copy()

for col in columns:
  percentile_99_value = gross_earn.quantile(0.99)
  limiter = new_dataset[col]
  new_dataset = new_dataset[
      (limiter<=percentile_99_value)]

new_dataset.describe()
# Out:
#             rating  runtime_clear  gross_earn_clear
# count  4527.000000    4527.000000       4527.000000
# mean      6.656837     110.156616         45.087985
# std       0.958791      20.341929         54.275255
# min       1.500000      45.000000          0.000000
# 25%       6.100000      96.000000          6.685000
# 50%       6.700000     106.000000         27.370000
# 75%       7.300000     120.000000         60.500000
# max       9.300000     259.000000        322.740000

# %%
columns = ['runtime_clear', 'gross_earn_clear']
g = sns.PairGrid(new_dataset[columns])
g.map(sns.scatterplot, alpha=0.3)

# %% [markdown]
# **Выводы:**
#
# **1)** присутствует нелинейная зависимость между признаками:

# %% [markdown]
# ## 8. Анализ взаимосвязи двух категориальных признаков

# %% [markdown]
# ### *8.1. director - certificate*

# %%
dataset['certificate'].unique()
# Out:
# array(['15', '12A', 'X', 'U', '18', 'PG', '12', 'A', 'AA', 'R',
#        'Not Rated', 'Rejected', 'UA', 'PG-13', '(Banned)'], dtype=object)

# %%
directors = dataset['director'].unique()
len(directors)
# Out:
# 1954

# %%
dataset['director'].value_counts()
# Out:
# director
# Woody Allen           38
# Clint Eastwood        27
# Steven Spielberg      27
# Alfred Hitchcock      24
# Ridley Scott          21
#                       ..
# Sebastian Schipper     1
# Jerry Zaks             1
# Kinji Fukasaku         1
# Robin Swicord          1
# Tom Putnam             1
# Name: count, Length: 1954, dtype: int64

# %%
directors_top_5 = dataset['director'].value_counts()[:5].index
directors_top_5
# Out:
# Index(['Woody Allen', 'Clint Eastwood', 'Steven Spielberg', 'Alfred Hitchcock',
#        'Ridley Scott'],
#       dtype='object', name='director')

# %%
labels = dataset['certificate'].unique()
colors = dict(zip(labels, plt.cm.tab20.colors[:len(labels)]))
colors
# Out:
# {'15': (0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  '12A': (0.6823529411764706, 0.7803921568627451, 0.9098039215686274),
#  'X': (1.0, 0.4980392156862745, 0.054901960784313725),
#  'U': (1.0, 0.7333333333333333, 0.47058823529411764),
#  '18': (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  'PG': (0.596078431372549, 0.8745098039215686, 0.5411764705882353),
#  '12': (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  'A': (1.0, 0.596078431372549, 0.5882352941176471),
#  'AA': (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  'R': (0.7725490196078432, 0.6901960784313725, 0.8352941176470589),
#  'Not Rated': (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  'Rejected': (0.7686274509803922, 0.611764705882353, 0.5803921568627451),
#  'UA': (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  'PG-13': (0.9686274509803922, 0.7137254901960784, 0.8235294117647058),
# ...

# %%
for director in directors_top_5:
  df = dataset['director']

  certificate_counts = dataset['certificate'].value_counts()[:5]
  labels = certificate_counts.index

  plt.title(director)
  plt.pie(certificate_counts.values, labels = labels, colors = [colors[key] for key in labels], autopct='%.1f%%')
  plt.show()

# %% [markdown]
# **Выводы:**
# **1)** на диаграмме видно, что распределение кассовых сборов (или другого признака) варьируется в зависимости от возрастного рейтинга фильмов. Это указывает на возможную взаимосвязь между признаками.
#
# **2)**
# 12A: Имеет высокие средние значения (18.5%), что может указывать на популярность фильмов с этим рейтингом
#
# 15: Имеет средние значения (15.4%), что говорит об умеренной популярности
#
# 18: Более низкие значения (8.5%), что может быть связано с ограниченной аудиторией из-за возрастных ограничений
#
# PG: Показывает высокие значения (14.4%), что указывает на популярность среди семейной аудитории

# %% [markdown]
# ### **8.2. director - rating*

# %%
#directors_top_5 уже есть
labels_uni = dataset['rating'].unique()
colors_2 = dict(zip(labels_uni, plt.cm.tab20.colors[:len(labels_uni)]))
colors_2
# Out:
# {9.3: (0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  9.2: (0.6823529411764706, 0.7803921568627451, 0.9098039215686274),
#  9.0: (1.0, 0.4980392156862745, 0.054901960784313725),
#  8.9: (1.0, 0.7333333333333333, 0.47058823529411764),
#  8.8: (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  8.7: (0.596078431372549, 0.8745098039215686, 0.5411764705882353),
#  8.6: (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  8.5: (1.0, 0.596078431372549, 0.5882352941176471),
#  8.4: (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  8.3: (0.7725490196078432, 0.6901960784313725, 0.8352941176470589),
#  8.2: (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  8.1: (0.7686274509803922, 0.611764705882353, 0.5803921568627451),
#  8.0: (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  7.9: (0.9686274509803922, 0.7137254901960784, 0.8235294117647058),
# ...

# %%
'''for director in directors_top_5:
  df = dataset['director']

  rating_counts = dataset['rating'].value_counts()[:5]
  labels_2 = rating_count.index

  plt.title(director)
  plt.pie(rating_count.values, labels = labels_2, colors = [colors_2[key] for key in labels_uni], autopct='%.1f%%')
  plt.show()'''

#что-то пошло здесь не так, прошу не обращать внимания
# Out:
# "for director in directors_top_5:\n  df = dataset['director']\n\n  rating_counts = dataset['rating'].value_counts()[:5]\n  labels_2 = rating_count.index\n\n  plt.title(director)\n  plt.pie(rating_count.values, labels = labels_2, colors = [colors_2[key] for key in labels_uni], autopct='%.1f%%')\n  plt.show()"

# %% [markdown]
# ## 9. Анализ взаимосвязи количественного и категориального признаков

# %% [markdown]
# ### *9.1. certificate - gross_earn_clear*

# %%
certificate_gross_group = dataset.groupby('certificate')['gross_earn_clear'].median()
certificate_gross_group
# Out:
# certificate
# (Banned)        NaN
# 12           41.580
# 12A          42.650
# 15           18.840
# 18           14.945
# A            16.140
# AA           27.620
# Not Rated     0.060
# PG           44.340
# PG-13         4.840
# R             1.110
# Rejected      0.050
# U            56.700
# UA           54.230
# X            14.750
# Name: gross_earn_clear, dtype: float64

# %%
dataset.groupby('certificate')['gross_earn_clear'].describe()
# Out:
#               count       mean         std    min      25%     50%      75%  \
# certificate
# (Banned)        0.0        NaN         NaN    NaN      NaN     NaN      NaN
# 12            269.0  60.113048   66.805332   0.04  20.5500  41.580   72.220
# 12A           757.0  77.310925  100.261041   0.00  15.2700  42.650   95.000
# 15           1719.0  33.451798   42.503809   0.00   3.6100  18.840   45.870
# 18            600.0  26.607200   34.639021   0.00   2.5375  14.945   36.875
# A             126.0  37.906190   50.157244   0.01   3.3925  16.140   51.245
# AA             52.0  38.855769   37.479422   0.02   7.2700  27.620   57.635
# Not Rated       5.0   3.830000    8.231376   0.01   0.0200   0.060    0.510
# PG            581.0  64.011360   66.772893   0.01  18.6000  44.340   81.060
# PG-13           9.0  11.922222   14.814578   0.02   1.5000   4.840   22.520
# R              11.0   3.487273    4.859718   0.00   0.2150   1.110    5.395
# ...

# %%
sns.boxplot(x=certificate_gross_group.index, y=certificate_gross_group.values)
plt.show()

# %%
dataset['certificate'].value_counts()
# Out:
# certificate
# 15           1843
# 12A           788
# 18            659
# PG            614
# U             362
# 12            278
# A             186
# X             134
# AA             59
# R              12
# UA             11
# PG-13          11
# Not Rated       7
# Rejected        5
# (Banned)        1
# Name: count, dtype: int64

# %% [markdown]
# По итогу оценки видно, что крупных классов - 8, поэтому ограничим диаграмму топ-8 классов

# %%
certificate_list = dataset['certificate'].value_counts().index[:8]
certificate_list
# Out:
# Index(['15', '12A', '18', 'PG', 'U', '12', 'A', 'X'], dtype='object', name='certificate')

# %%
dataset_certificate_top_8 = dataset[dataset['certificate'].isin(certificate_list)]
print(dataset_certificate_top_8.shape)
dataset_certificate_top_8.head(3)
# Out:
# (4864, 13)
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime          genre  rating  \
# 0  The Shawshank Redemption          15  142 min          Drama     9.3
# 1            Hababam Sinifi         12A   87 min  Comedy, Drama     9.2
# 2             The Godfather           X  175 min   Crime, Drama     9.2
#
#                                                about              director  \
# 0  Two imprisoned men bond over a number of years...        Frank Darabont
# 1  Lazy, uneducated students share a very close b...         Ertem Egilmez
# 2  The aging patriarch of an organized crime dyna...  Francis Ford Coppola
#
#                                                stars      votes gross_earn  \
# ...

# %%
cer_gross_median = dataset_certificate_top_8.groupby('certificate')['gross_earn_clear'].median()
cer_gross_median
# Out:
# certificate
# 12     41.580
# 12A    42.650
# 15     18.840
# 18     14.945
# A      16.140
# PG     44.340
# U      56.700
# X      14.750
# Name: gross_earn_clear, dtype: float64

# %%
sns.boxplot(x=cer_gross_median.index, y=cer_gross_median.values)
plt.axis(ymin=0, ymax=250)
plt.show()

# %% [markdown]
# **Выводы:**
#
# **1)** я не вижу взаимосвязи между признаками
#
# **2)**
# медианные сборы:
#   Наиболее высокие у U (56.70) и 12A (42.65).
#   Наиболее низкие у Rejected (0.05) и R (1.11)
#
# тоже самое и для mean
#
# наименьший разброс сборов: у Rejected (std = 1.77) и R (std = 4.86)
#
# наибольший разброс сборов: у категорий 12A (std = 100.26) и U (std = 92.47)
#
#
# **3)** самое большое значение медианы: U - 56.700, следовательно фильмы этого класса самые прибыльные. минимальное значение: X - 14.750, это самый не прибыльный класс

# %% [markdown]
# ## 10. Общий вывод

# %% [markdown]
# данные показывают значительную вариативность, так что необходима тщательная предобработка и анализ
#
# возрастной рейтинг фильма является важным фактором, влияющим на его доходы. фильмы с рейтингами 12A и U показывают наибольшую прибыль, афильмы с рейтингами 18, Rejected и R — наименьшую
#
# наличие выбросов и нелинейных зависимостей указывает на необходимость использования более сложных методов анализа для изучения взаимосвязей между признаками
#
# таким образом, разведочный анализ данных позволил выявить ключевые закономерности и особенности распределения доходов фильмов в зависимости от их возрастного рейтинга, а также определить направления для дальнейшего анализа
