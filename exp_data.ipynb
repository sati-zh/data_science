# %%
# !pip install --upgrade gdown

# %%
# !gdown --id 1LjVzFpLoB0vfB1wSuc7PxZ0VyiJFNOVS
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1LjVzFpLoB0vfB1wSuc7PxZ0VyiJFNOVS
# To: /content/housing_market_dataset.csv
# 100% 29.4M/29.4M [00:00<00:00, 140MB/s]

# %%
import pandas as pd
dataset = pd.read_csv('housing_market_dataset.csv')
dataset.head()
# Out:
#                                                  url  \
# 0  https://move.ru/objects/moskva_ulica_baykalska...
# 1  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 2  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 3  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 4  https://move.ru/objects/prodaetsya_3-komn_kvar...
#
#                                            Заголовок  \
# 0  Продажа 1-комнатной квартиры, 31 м², Москва, у...
# 1  Продам 2-комнатную квартиру, 83.2 м², Москва, ...
# 2  Продаю 2-комнатную квартиру, 89.6 м², Москва, ...
# 3  Продам 2-комнатную квартиру, 55.8 м², Москва, ...
# 4  Продаю 3-комнатную квартиру, 128 м², Москва, Д...
#
#                                          Новостройка Этап строительства  \
# 0                                                NaN                NaN
# 1         ЖК City Park («Сити Парк»), м. Выставочная            Отделка
# 2  ЖК Silver (ЖК «Резиденции кинематографистов»),...            Отделка
# ...

# %%
import matplotlib.pyplot as plt

# %%
dataset['Площадь кухни']
# Out:
# 0         5.5 м²
# 1        33.4 м²
# 2            NaN
# 3            NaN
# 4        17.1 м²
#           ...
# 12996       8 м²
# 12997       8 м²
# 12998      14 м²
# 12999       8 м²
# 13000       8 м²
# Name: Площадь кухни, Length: 13001, dtype: object

# %%
#вопрос 1
len(dataset['Площадь кухни'].unique())

#dataset['Площадь кухни'].unique()
# Out:
# 310

# %%
#вопрос 2
#вопрос 8
class_home_clean = dataset['Класс жилья'].dropna()
plt.hist(class_home_clean, bins = 10)
#class_home = dataset['Класс жилья']

plt.show()

# %%
#вопрос 6
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13001 entries, 0 to 13000
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            13001 non-null  object
#  1   Заголовок                      13001 non-null  object
#  2   Новостройка                    6080 non-null   object
#  3   Этап строительства             5812 non-null   object
#  4   Год постройки                  7025 non-null   float64
#  5   Класс жилья                    5812 non-null   object
#  6   МЦК                            7633 non-null   object
#  7   Кол-во просмотров              13001 non-null  int64
#  8   Кол-во просмотров сегодня      7224 non-null   float64
#  9   Описание                       12263 non-null  object
#  10  Информация                     13001 non-null  object
#  11  Адрес                          13001 non-null  object
# ...

# %%
#вопрос 10
dataset['Площадь кухни'].notnull().sum()
# Out:
# 11821

# %%
#вопрос 13
dataset['Год постройки'].min()
# Out:
# 1876.0

# %%
#вопрос 15
len(dataset)
# Out:
# 13001

# %%
#вопрос 14
year_of_construction = dataset['Год постройки']
percentile_70_value = year_of_construction.quantile(0.70)
print('70-й процентиль года постройки: ', percentile_70_value)
# Out:
# 70-й процентиль года постройки:  2019.0

# %%
#вопрос 12
dataset['Класс жилья'].value_counts()
# Out:
# Класс жилья
# Бизнес класс     3415
# Комфорт класс    1875
# Элит класс        345
# Эконом класс      177
# Name: count, dtype: int64

# %%
#начало вопрос 4
flat_types = dataset['Класс жилья'].unique()
flat_types = flat_types[1:]
flat_types
# Out:
# array(['Элит класс', 'Бизнес класс', 'Эконом класс', 'Комфорт класс'],
#       dtype=object)

# %%
labels = dataset['Тип здания'].unique()
colors = dict(zip(labels, plt.cm.tab20.colors[:len(labels)]))
colors
# Out:
# {'Панельное': (0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  'Монолитно-кирпичный': (0.6823529411764706,
#   0.7803921568627451,
#   0.9098039215686274),
#  'Монолитное': (1.0, 0.4980392156862745, 0.054901960784313725),
#  'Монолитный': (1.0, 0.7333333333333333, 0.47058823529411764),
#  'Кирпичное': (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  nan: (0.596078431372549, 0.8745098039215686, 0.5411764705882353),
#  'Блочное': (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  'Монолитно-кирпичное': (1.0, 0.596078431372549, 0.5882352941176471),
#  'Сталинское': (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  'Панельный': (0.7725490196078432, 0.6901960784313725, 0.8352941176470589),
#  'Панельно-кирпичное': (0.5490196078431373,
#   0.33725490196078434,
#   0.29411764705882354)}

# %%
#конец вопрос 4
import matplotlib.pyplot as plt

for flat_type in flat_types:
  df = dataset[dataset['Класс жилья']==flat_type]

  class_counts = df['Тип здания'].value_counts()
  labels =class_counts.index

  plt.title(flat_type)
  patches, texts = plt.pie(
      class_counts.values,
      labels = labels,
      colors = [colors[key] for key in labels],
      textprops=dict(color="w")
      )
  plt.legend(patches, labels, title="Типы здания", loc="upper center", bbox_to_anchor=(1, 0, 0.5, 1))

  plt.show()

# %%
dataset.groupby('Класс жилья')["Очищенная цена за м²"].describe()
# Out:
#                 count           mean            std      min       25%  \
# Класс жилья
# Бизнес класс   3415.0  217850.375403   55761.695478   7199.0  189125.0
# Комфорт класс  1875.0  129315.616533   35933.283271  72030.0  101870.5
# Эконом класс    177.0  163069.536723   55864.258999   8273.0  120732.0
# Элит класс      345.0  373067.913043  207956.103586  86667.0  275000.0
#
#                     50%       75%        max
# Класс жилья
# Бизнес класс   220000.0  246898.5  1005747.0
# Комфорт класс  115301.0  156596.5   260870.0
# Эконом класс   154955.0  200000.0   288462.0
# Элит класс     307432.0  407305.0  2277778.0

# %%
#вопрос 3
import seaborn as sns
from matplotlib import pyplot as plt
sns.jointplot(x=dataset["Год постройки"], y=dataset["Очищенная цена за м²"],size=10, alpha=0.2)
plt.show()

# %%
dataset['Этап строительства'].unique()
# Out:
# array([nan, 'Отделка', 'Сдан', 'Возведение стен', 'В проекте', 'Площадка',
#        'Заморожено', 'Котлован'], dtype=object)

# %%
# уже не помню какой воспрос
#construction_stage = dataset['Этап строительства'].dropna()
#plt.hist(construction_stage, bins = 10)


construction_stage_2 = dataset['Этап строительства'].value_counts()
plt.barh(construction_stage_2.index, construction_stage_2.values)
plt.show()

# %%
#начало вопрос 5
a = dataset['Количество комнат'].dropna()
plt.hist(a, bins = 10)
# Out:
# (array([1.2457e+04, 5.2000e+02, 2.2000e+01, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
a = dataset['Количество комнат'].dropna()
plt.boxplot(a)
plt.show()

# %%
b = dataset['Этажность']
plt.hist(b, bins = 10)
# Out:
# (array([3.165e+03, 5.847e+03, 2.876e+03, 7.440e+02, 2.020e+02, 1.590e+02,
#         1.000e+00, 2.000e+00, 1.000e+00, 4.000e+00]),
#  array([  1. ,  10.9,  20.8,  30.7,  40.6,  50.5,  60.4,  70.3,  80.2,
#          90.1, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
#конец вопрос 5
c = dataset['Этажность'].dropna()
plt.boxplot(c)
plt.show()
