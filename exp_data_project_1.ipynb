# %% [markdown]
# ## 2. Загрузка датасета

# %%
# при ошибке загрузки в текущей версии gdown необходимо его обновить
# !pip install --upgrade gdown

# %%
# !gdown --id 1SQihqE13h5sEVzLSaBn9f2l_FdMtxNQb
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1SQihqE13h5sEVzLSaBn9f2l_FdMtxNQb
# To: /content/movies.csv
# 100% 1.89M/1.89M [00:00<00:00, 80.4MB/s]

# %% [markdown]
# ## 3. Подгрузка данных в питон и начало работы с ними

# %%
import pandas as pd

# %%
dataset = pd.read_csv('movies.csv')

# %%
dataset.head()
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime                      genre  \
# 0  The Shawshank Redemption          15  142 min                      Drama
# 1           The Dark Knight         12A  152 min       Action, Crime, Drama
# 2                 Inception         12A  148 min  Action, Adventure, Sci-Fi
# 3                Fight Club          18  139 min                      Drama
# 4              Pulp Fiction          18  154 min               Crime, Drama
#
#    rating                                              about  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.0  When the menace known as the Joker wreaks havo...
# ...

# %% [markdown]
# ## 4. Оценка размеров датасета, наличия дубликатов и пропусков

# %%
dataset.shape
# Out:
# (5000, 11)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   poster       5000 non-null   object
#  1   title        5000 non-null   object
#  2   certificate  5000 non-null   object
#  3   runtime      5000 non-null   object
#  4   genre        4970 non-null   object
#  5   rating       5000 non-null   float64
#  6   about        4986 non-null   object
#  7   director     5000 non-null   object
#  8   stars        5000 non-null   object
#  9   votes        5000 non-null   object
#  10  gross_earn   4585 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 429.8+ KB

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset['gross_earn'].isna().sum()
# Out:
# 415

# %% [markdown]
# **Выводы:**
#
# 1) размер датасета (5000, 11)
#
# 2) вся инфрормация в датасете делиться на object и float64. предобработка нужна для votes
#
# 3) дубликатов нет
#
# 4) есть пропуски. предобработка нужна, но на данный момент я не совсем понимаю что делать
#
# 5) любой анализ ['gross_earn'] будет проблематичен, даже если пропуски заполнить средним значением, это все равно будет не тот результат

# %%
rows_with_missing_values = dataset[dataset.isna().any(axis=1)]
rows_with_missing_values

#я решила вывести строки с пропущ значением, просто посмотреть на них
# Out:
#                                                  poster  \
# 359   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 394   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 430   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 525   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 547   https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                 ...
# 4986  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4988  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4994  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4996  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4997  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                        title certificate         runtime  \
# 359    It's a Wonderful Life           U         130 min
# 394             Hotel Rwanda         12A         121 min
# 430                 Downfall          15         156 min
# 525    To Kill a Mockingbird           A         129 min
# ...

# %%
dataset.isna().sum()
#становится ясно что больше всего пропусков в 'gross_earn'
# Out:
# poster           0
# title            0
# certificate      0
# runtime          0
# genre           30
# rating           0
# about           14
# director         0
# stars            0
# votes            0
# gross_earn     415
# dtype: int64

# %% [markdown]
# ## 5. Обработка колонок runtime и gross_earn: приведение к числовому типу

# %% [markdown]
# ### *5.1. runtime*

# %%
dataset['runtime']
# Out:
# 0              142 min
# 1              152 min
# 2              148 min
# 3              139 min
# 4              154 min
#              ...
# 4995           102 min
# 4996            94 min
# 4997    Drama, Romance
# 4998            92 min
# 4999           120 min
# Name: runtime, Length: 5000, dtype: object

# %%
dataset['runtime'].unique()
# Out:
# array(['142 min', '152 min', '148 min', '139 min', '154 min', '178 min',
#        '136 min', '201 min', '175 min', '164 min', '179 min', '127 min',
#        '143 min', '155 min', '140 min', '165 min', '169 min', '121 min',
#        '118 min', '162 min', '153 min', '151 min', '195 min', '113 min',
#        '130 min', '124 min', '122 min', '194 min', '132 min', '202 min',
#        '138 min', '119 min', '189 min', '180 min', '137 min', '106 min',
#        '111 min', '116 min', '145 min', '110 min', '98 min', '107 min',
#        '126 min', '100 min', '131 min', '133 min', '103 min', '108 min',
#        '96 min', '99 min', '115 min', '88 min', '120 min', '81 min',
#        '135 min', '146 min', '117 min', '104 min', '92 min', '91 min',
#        '102 min', '149 min', '170 min', '112 min', '101 min', '141 min',
#        '144 min', '114 min', '150 min', '90 min', '161 min', '128 min',
#        '93 min', '129 min', '166 min', '147 min', '134 min', '109 min',
# ...

# %%
import re

# %%
def clear_runtime(runtime):
  digits = re.sub(r"\D+", "", runtime)
  return digits

# %%
dataset['runtime']
# Out:
# 0              142 min
# 1              152 min
# 2              148 min
# 3              139 min
# 4              154 min
#              ...
# 4995           102 min
# 4996            94 min
# 4997    Drama, Romance
# 4998            92 min
# 4999           120 min
# Name: runtime, Length: 5000, dtype: object

# %%
dataset['runtime'].apply(clear_runtime)
#теперь остались цифры
# Out:
# 0       142
# 1       152
# 2       148
# 3       139
# 4       154
#        ...
# 4995    102
# 4996     94
# 4997
# 4998     92
# 4999    120
# Name: runtime, Length: 5000, dtype: object

# %%
dataset['runtime_clear'] = dataset['runtime'].apply(clear_runtime)

# %%
dataset['runtime_clear']
# Out:
# 0       142
# 1       152
# 2       148
# 3       139
# 4       154
#        ...
# 4995    102
# 4996     94
# 4997
# 4998     92
# 4999    120
# Name: runtime_clear, Length: 5000, dtype: object

# %%
dataset['runtime_clear'].isna().sum()
# Out:
# 0

# %%
dataset['runtime_clear'][4997]
# Out:
# ''

# %%
type(dataset['runtime_clear'][4997])
# Out:
# str

# %%
dataset = dataset[dataset['runtime_clear']!='']

# %%
dataset.shape
# Out:
# (4970, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4970 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   poster         4970 non-null   object
#  1   title          4970 non-null   object
#  2   certificate    4970 non-null   object
#  3   runtime        4970 non-null   object
#  4   genre          4970 non-null   object
#  5   rating         4970 non-null   float64
#  6   about          4956 non-null   object
#  7   director       4970 non-null   object
#  8   stars          4970 non-null   object
#  9   votes          4970 non-null   object
#  10  gross_earn     4574 non-null   object
#  11  runtime_clear  4970 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 504.8+ KB

# %%
dataset['runtime_clear'].astype(int)
# Out:
# 0       142
# 1       152
# 2       148
# 3       139
# 4       154
#        ...
# 4994     93
# 4995    102
# 4996     94
# 4998     92
# 4999    120
# Name: runtime_clear, Length: 4970, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4970 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   poster         4970 non-null   object
#  1   title          4970 non-null   object
#  2   certificate    4970 non-null   object
#  3   runtime        4970 non-null   object
#  4   genre          4970 non-null   object
#  5   rating         4970 non-null   float64
#  6   about          4956 non-null   object
#  7   director       4970 non-null   object
#  8   stars          4970 non-null   object
#  9   votes          4970 non-null   object
#  10  gross_earn     4574 non-null   object
#  11  runtime_clear  4970 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 504.8+ KB

# %% [markdown]
# ### *5.2. gross_earn*

# %%
dataset.head()
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime                      genre  \
# 0  The Shawshank Redemption          15  142 min                      Drama
# 1           The Dark Knight         12A  152 min       Action, Crime, Drama
# 2                 Inception         12A  148 min  Action, Adventure, Sci-Fi
# 3                Fight Club          18  139 min                      Drama
# 4              Pulp Fiction          18  154 min               Crime, Drama
#
#    rating                                              about  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.0  When the menace known as the Joker wreaks havo...
# ...

# %%
dataset['gross_earn']
# Out:
# 0        $28.34M
# 1       $534.86M
# 2       $292.58M
# 3        $37.03M
# 4       $107.93M
#           ...
# 4994         NaN
# 4995      $9.40M
# 4996         NaN
# 4998      $6.67M
# 4999      $8.20M
# Name: gross_earn, Length: 4970, dtype: object

# %%
def clear_gross_earn(gross_earn):
  #digits = re.sub(r"^0-9.", "", gross_earn)
  digits = re.sub(r"[^\d\.]", "", gross_earn)
  return digits

# %%
dataset['gross_earn'].apply(clear_gross_earn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-d1486cb428e8> in <cell line: 0>()
# ----> 1 dataset['gross_earn'].apply(clear_gross_earn)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# ...

# %%
dataset['gross_earn'].isna().sum()
# Out:
# 396

# %%
import numpy as np

# %%
def clear_gross_earn(gross_earn):
  if pd.isna(gross_earn):
    return np.nan
  else:
    return re.sub('[^\d\.]', '', gross_earn)
    # ^-отрицание
    # \d - любая цифра (или 0-9)
    # \. - точка

# %%
dataset['gross_earn'].apply(clear_gross_earn)
# Out:
# 0        28.34
# 1       534.86
# 2       292.58
# 3        37.03
# 4       107.93
#          ...
# 4994       NaN
# 4995      9.40
# 4996       NaN
# 4998      6.67
# 4999      8.20
# Name: gross_earn, Length: 4970, dtype: object

# %%
dataset['gross_earn_clear'] = dataset['gross_earn'].apply(clear_gross_earn)

# %%
dataset['gross_earn_clear']
# Out:
# 0        28.34
# 1       534.86
# 2       292.58
# 3        37.03
# 4       107.93
#          ...
# 4994       NaN
# 4995      9.40
# 4996       NaN
# 4998      6.67
# 4999      8.20
# Name: gross_earn_clear, Length: 4970, dtype: object

# %%
dataset['gross_earn_clear'].astype(float)
# Out:
# 0        28.34
# 1       534.86
# 2       292.58
# 3        37.03
# 4       107.93
#          ...
# 4994       NaN
# 4995      9.40
# 4996       NaN
# 4998      6.67
# 4999      8.20
# Name: gross_earn_clear, Length: 4970, dtype: float64

# %%
dataset['gross_earn_clear']
# Out:
# 0        28.34
# 1       534.86
# 2       292.58
# 3        37.03
# 4       107.93
#          ...
# 4994       NaN
# 4995      9.40
# 4996       NaN
# 4998      6.67
# 4999      8.20
# Name: gross_earn_clear, Length: 4970, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4970 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   poster            4970 non-null   object
#  1   title             4970 non-null   object
#  2   certificate       4970 non-null   object
#  3   runtime           4970 non-null   object
#  4   genre             4970 non-null   object
#  5   rating            4970 non-null   float64
#  6   about             4956 non-null   object
#  7   director          4970 non-null   object
#  8   stars             4970 non-null   object
#  9   votes             4970 non-null   object
#  10  gross_earn        4574 non-null   object
#  11  runtime_clear     4970 non-null   object
#  12  gross_earn_clear  4574 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 543.6+ KB

# %% [markdown]
# ## 6. Сортировка по рейтингу

# %%
dataset
# Out:
#                                                  poster  \
# 0     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4     https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                 ...
# 4994  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4995  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4996  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4998  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4999  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                 title certificate  runtime  \
# 0            The Shawshank Redemption          15  142 min
# 1                     The Dark Knight         12A  152 min
# 2                           Inception         12A  148 min
# ...

# %%
sorted_dataset = dataset.sort_values(by=['rating'], ascending=False)
sorted_dataset.head()
# Out:
#                                                  poster  \
# 0     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3788  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 9     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 32    https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24    https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                          title certificate  runtime  \
# 0     The Shawshank Redemption          15  142 min
# 3788            Hababam Sinifi         12A   87 min
# 9                The Godfather           X  175 min
# 32      The Godfather: Part II           X  202 min
# 24            Schindler's List          15  195 min
#
#                           genre  rating  \
# 0                         Drama     9.3
# 3788              Comedy, Drama     9.2
# 9                  Crime, Drama     9.2
# 32                 Crime, Drama     9.0
# 24    Biography, Drama, History     9.0
#
# ...

# %% [markdown]
# ## 7. Переопределение индексов

# %%
sorted_dataset.reset_index(drop=True, inplace=True)
sorted_dataset.head()
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime                      genre  \
# 0  The Shawshank Redemption          15  142 min                      Drama
# 1            Hababam Sinifi         12A   87 min              Comedy, Drama
# 2             The Godfather           X  175 min               Crime, Drama
# 3    The Godfather: Part II           X  202 min               Crime, Drama
# 4          Schindler's List          15  195 min  Biography, Drama, History
#
#    rating                                              about  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.2  Lazy, uneducated students share a very close b...
# ...

# %% [markdown]
# ## 8. Сохранение датасета

# %%
#sorted_dataset.to_csv('dataset.csv')
sorted_dataset.to_csv('movies_clean_1.csv', index=False)
#sorted_dataset.to_csv('/home/sati/Загрузки/dataset.csv', index=False)

# %%
from google.colab import files
files.download('movies_clean_1.csv')

# %%
dataset.head(2)
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime                 genre  \
# 0  The Shawshank Redemption          15  142 min                 Drama
# 1           The Dark Knight         12A  152 min  Action, Crime, Drama
#
#    rating                                              about  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.0  When the menace known as the Joker wreaks havo...
#
#             director                                              stars  \
# 0     Frank Darabont  ('Tim Robbins',), ('Morgan Freeman',), ('Bob G...
# 1  Christopher Nolan  ('Christian Bale',), ('Heath Ledger',), ('Aaro...
#
#        votes gross_earn runtime_clear gross_earn_clear
# 0  26,26,905    $28.34M           142            28.34
# 1  25,98,173   $534.86M           152           534.86
